# %%
# Out:
# Fetching Ames Housing dataset...
#
# --- Model Evaluation Results ---
# Linear Regression    | RMSE: $83,088.77 | R² Score: 0.0999
# Ridge Regression     | RMSE: $32,654.34 | R² Score: 0.8610
# Lasso Regression     | RMSE: $35,009.33 | R² Score: 0.8402
